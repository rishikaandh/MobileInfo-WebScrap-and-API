# %%
from flask import Flask, jsonify, request
import pandas as pd
import socket
import sys

app = Flask(__name__)

# Read the dataset
mobile_data = pd.read_excel('mob_info.xlsx')

def is_port_available(port):
    try:
        with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
            s.bind(('127.0.0.1', port))
        return True
    except OSError:
        return False

def find_available_port(start_port, max_attempts=10):
    port = start_port
    attempts = 0
    while attempts < max_attempts:
        if is_port_available(port):
            return port
        port += 1
        attempts += 1
    return None

if __name__ == '__main__':
    # Find an available port starting from 5009
    available_port = find_available_port(start_port=5009)

    if available_port is None:
        print("Error: Unable to find an available port.")
        sys.exit(1)

    # Update the app run statement with the available port
    app.run(debug=True, port=available_port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5009
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
