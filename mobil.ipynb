# %%
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (4.12.2)
# Requirement already satisfied: pandas in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\rishikaandh\anaconda3\envs\tf\lib\site-packages)

# %% [markdown]
# *web scraping of mobile details from flipkart*

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def get_flipkart_mobile_info(page_number=1):
    base_url = "https://www.flipkart.com"
    url = f"{base_url}/mobiles/pr?sid=tyy%2C4io&marketplace=FLIPKART&page={page_number}"

    mobile_info = []

    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        for product_card in soup.find_all('div', class_='_1AtVbE'):
            name_tag = product_card.find('div', class_='_4rR01T')
            price_tag = product_card.find('div', class_='_30jeq3')
            warranty_tag = product_card.find('div', {'class': '_24_Dny'})
            ram_storage_tag = product_card.find_all('li', class_='rgWa7D')

            brand_tag = product_card.find('div', class_='_2WkVRV')
            rating_tag = product_card.find('div', class_='_3LWZlK')
            display_size_tag = product_card.find('li', {'title': 'Display Size'})
            camera_tag = product_card.find('li', {'title': 'Primary Camera'})

            if name_tag and price_tag:
                mobile_name = name_tag.text.strip()
                mobile_price = price_tag.text.strip()
                mobile_warranty = warranty_tag.text.strip() if warranty_tag else "N/A"

                ram_storage_info = {"RAM": "N/A", "Storage": "N/A"}
                for info in ram_storage_tag:
                    text = info.text.strip()
                    if "RAM" in text:
                        ram_storage_info["RAM"] = text
                    elif "ROM" in text or "Storage" in text:
                        ram_storage_info["Storage"] = text

                brand = brand_tag.text.strip() if brand_tag else "N/A"
                rating = rating_tag.text.strip() if rating_tag else "N/A"
                display_size = display_size_tag.text.strip() if display_size_tag else "N/A"
                primary_camera = camera_tag.text.strip() if camera_tag else "N/A"

                mobile_info.append({
                    "Name": mobile_name,
                    "Price": mobile_price,
                    "Warranty": mobile_warranty,
                    "RAM": ram_storage_info["RAM"],
                    "Storage": ram_storage_info["Storage"],
                    "Brand": brand,
                    "Rating": rating,
                    "Display Size": display_size,
                    "Primary Camera": primary_camera
                })

        return mobile_info
    elif response.status_code == 429:
        print(f"Rate limit reached. Retrying after 3 seconds...")
        time.sleep(3)
        return get_flipkart_mobile_info(page_number=page_number)  # Retry the request after a delay
    else:
        print(f"Failed to retrieve the page {page_number}. Status code: {response.status_code}")
        print(f"HTML Content for page {page_number}: {response.content}")
        return None

# Create an empty list to store all DataFrames
all_dfs = []

# Iterate through pages from 1 to 400
for page_num in range(1, 42):
    mobile_info_page = get_flipkart_mobile_info(page_number=page_num)

    if mobile_info_page:
        try:
            df_page = pd.DataFrame(mobile_info_page)
        except Exception as e:
            print(f"Error creating DataFrame for page {page_num}: {e}")
            print(f"HTML Content for page {page_num}: {response.content}")
            continue  # Skip to the next iteration if DataFrame creation fails

        all_dfs.append(df_page)
        print(f"Mobile Phone Information (Page {page_num}) appended to the overall list.")
    else:
        print(f"No data found for page {page_num}. Skipping to the next page.")

# Concatenate all DataFrames in the list into a single DataFrame
all_mobile_info_df = pd.concat(all_dfs, ignore_index=True)

# Display the overall DataFrame
print(all_mobile_info_df)
# Out:
# Mobile Phone Information (Page 1) appended to the overall list.
# Mobile Phone Information (Page 2) appended to the overall list.
# Rate limit reached. Retrying after 3 seconds...
# Mobile Phone Information (Page 3) appended to the overall list.
# Mobile Phone Information (Page 4) appended to the overall list.
# Mobile Phone Information (Page 5) appended to the overall list.
# Mobile Phone Information (Page 6) appended to the overall list.
# Mobile Phone Information (Page 7) appended to the overall list.
# Mobile Phone Information (Page 8) appended to the overall list.
# Mobile Phone Information (Page 9) appended to the overall list.
# Mobile Phone Information (Page 10) appended to the overall list.
# Mobile Phone Information (Page 11) appended to the overall list.
# Mobile Phone Information (Page 12) appended to the overall list.
# Mobile Phone Information (Page 13) appended to the overall list.
# Mobile Phone Information (Page 14) appended to the overall list.
# Mobile Phone Information (Page 15) appended to the overall list.
# Mobile Phone Information (Page 16) appended to the overall list.
# Mobile Phone Information (Page 17) appended to the overall list.
# Mobile Phone Information (Page 18) appended to the overall list.
# Mobile Phone Information (Page 19) appended to the overall list.
# Mobile Phone Information (Page 20) appended to the overall list.
# Rate limit reached. Retrying after 3 seconds...
# Rate limit reached. Retrying after 3 seconds...
# Mobile Phone Information (Page 21) appended to the overall list.
# Mobile Phone Information (Page 22) appended to the overall list.
# Mobile Phone Information (Page 23) appended to the overall list.
# Mobile Phone Information (Page 24) appended to the overall list.
# Mobile Phone Information (Page 25) appended to the overall list.
# Mobile Phone Information (Page 26) appended to the overall list.
# Rate limit reached. Retrying after 3 seconds...
# Mobile Phone Information (Page 27) appended to the overall list.
# Mobile Phone Information (Page 28) appended to the overall list.
# Mobile Phone Information (Page 29) appended to the overall list.
# Rate limit reached. Retrying after 3 seconds...
# Rate limit reached. Retrying after 3 seconds...
# Mobile Phone Information (Page 30) appended to the overall list.
# Rate limit reached. Retrying after 3 seconds...
# Mobile Phone Information (Page 31) appended to the overall list.
# Mobile Phone Information (Page 32) appended to the overall list.
# Mobile Phone Information (Page 33) appended to the overall list.
# Mobile Phone Information (Page 34) appended to the overall list.
# Rate limit reached. Retrying after 3 seconds...
# Mobile Phone Information (Page 35) appended to the overall list.
# Mobile Phone Information (Page 36) appended to the overall list.
# Mobile Phone Information (Page 37) appended to the overall list.
# Mobile Phone Information (Page 38) appended to the overall list.
# Mobile Phone Information (Page 39) appended to the overall list.
# Rate limit reached. Retrying after 3 seconds...
# Mobile Phone Information (Page 40) appended to the overall list.
# Rate limit reached. Retrying after 3 seconds...
# Mobile Phone Information (Page 41) appended to the overall list.
#                                                  Name      Price Warranty  \
# 0                     APPLE iPhone 15 (Black, 128 GB)    ₹73,999
# 1                        POCO C51 (Royal Blue, 64 GB)     ₹5,799
# 2                   vivo T2x 5G (Aurora Gold, 128 GB)    ₹14,999
# 3                     APPLE iPhone 15 (Green, 128 GB)    ₹73,999
# 4                 vivo T2x 5G (Glimmer Black, 128 GB)    ₹12,999
# ..                                                ...        ...      ...
# 979               vivo V25 5G (Elegant Black, 256 GB)    ₹26,790
# 980                        SAMSUNG Metro 313 Dual Sim     ₹2,399
# 981                vivo V25 5G (Surfing Blue, 256 GB)    ₹27,999
# 982                   itel S23 (Starry Black, 128 GB)     ₹8,399
# 983  APPLE iPhone 15 Pro Max (White Titanium, 512 GB)  ₹1,76,900
#
#                                               RAM     Storage Brand Rating  \
# 0                                             N/A  128 GB ROM   N/A    4.6
# 1     4 GB RAM | 64 GB ROM | Expandable Upto 1 TB         N/A   N/A      4
# 2                           8 GB RAM | 128 GB ROM         N/A   N/A    4.3
# 3                                             N/A  128 GB ROM   N/A    4.6
# 4                           6 GB RAM | 128 GB ROM         N/A   N/A    4.4
# ..                                            ...         ...   ...    ...
# 979                        12 GB RAM | 256 GB ROM         N/A   N/A    4.2
# 980  10 MB RAM | 2 MB ROM | Expandable Upto 16 GB         N/A   N/A    4.3
# 981                        12 GB RAM | 256 GB ROM         N/A   N/A    4.2
# 982                         8 GB RAM | 128 GB ROM         N/A   N/A    4.1
# 983                                           N/A  512 GB ROM   N/A    4.7
#
#     Display Size Primary Camera
# 0            N/A            N/A
# 1            N/A            N/A
# 2            N/A            N/A
# 3            N/A            N/A
# 4            N/A            N/A
# ..           ...            ...
# 979          N/A            N/A
# 980          N/A            N/A
# 981          N/A            N/A
# 982          N/A            N/A
# 983          N/A            N/A
#
# [984 rows x 9 columns]

# %% [markdown]
# dataset saved in a excel format

# %%
all_mobile_info_df.to_excel("mobile_info.xlsx", index=False)

# %% [markdown]
# cleaning and organising the dataset

# %%
import pandas as pd

# Load the Excel file into a DataFrame
file_path = 'mobile_info.xlsx'  # Replace with your file path
df = pd.read_excel(file_path)

# %%
df['RAMM'] = df['RAM'].str.split('|').str[0].str.strip()
df['ROM'] = df['RAM'].str.split('|').str[1:].apply(lambda x: '|'.join(x).strip() if isinstance(x, list) else None)
df[['Column1', 'Column2']] = df['Name'].str.extract(r'\(([^,]*),([^)]*)\)')
df['ROM'] = df['ROM'].fillna(df['Column2'])
df['Brand'] = df['Name'].str.split().str[0]

# %%
df
# Out:
#                                                  Name      Price  Warranty  \
# 0                     APPLE iPhone 15 (Black, 128 GB)    ₹73,999       NaN
# 1                        POCO C51 (Royal Blue, 64 GB)     ₹5,799       NaN
# 2                   vivo T2x 5G (Aurora Gold, 128 GB)    ₹14,999       NaN
# 3                     APPLE iPhone 15 (Green, 128 GB)    ₹73,999       NaN
# 4                 vivo T2x 5G (Glimmer Black, 128 GB)    ₹12,999       NaN
# ..                                                ...        ...       ...
# 979               vivo V25 5G (Elegant Black, 256 GB)    ₹26,790       NaN
# 980                        SAMSUNG Metro 313 Dual Sim     ₹2,399       NaN
# 981                vivo V25 5G (Surfing Blue, 256 GB)    ₹27,999       NaN
# 982                   itel S23 (Starry Black, 128 GB)     ₹8,399       NaN
# 983  APPLE iPhone 15 Pro Max (White Titanium, 512 GB)  ₹1,76,900       NaN
#
#                                               RAM     Storage    Brand  \
# 0                                             NaN  128 GB ROM    APPLE
# 1     4 GB RAM | 64 GB ROM | Expandable Upto 1 TB         NaN     POCO
# 2                           8 GB RAM | 128 GB ROM         NaN     vivo
# 3                                             NaN  128 GB ROM    APPLE
# 4                           6 GB RAM | 128 GB ROM         NaN     vivo
# ..                                            ...         ...      ...
# 979                        12 GB RAM | 256 GB ROM         NaN     vivo
# 980  10 MB RAM | 2 MB ROM | Expandable Upto 16 GB         NaN  SAMSUNG
# 981                        12 GB RAM | 256 GB ROM         NaN     vivo
# 982                         8 GB RAM | 128 GB ROM         NaN     itel
# 983                                           NaN  512 GB ROM    APPLE
#
#      Rating  Display Size  Primary Camera       RAMM  \
# 0       4.6           NaN             NaN        NaN
# 1       4.0           NaN             NaN   4 GB RAM
# 2       4.3           NaN             NaN   8 GB RAM
# 3       4.6           NaN             NaN        NaN
# 4       4.4           NaN             NaN   6 GB RAM
# ..      ...           ...             ...        ...
# 979     4.2           NaN             NaN  12 GB RAM
# 980     4.3           NaN             NaN  10 MB RAM
# 981     4.2           NaN             NaN  12 GB RAM
# 982     4.1           NaN             NaN   8 GB RAM
# 983     4.7           NaN             NaN        NaN
#
#                                   ROM         Column1  Column2
# 0                              128 GB           Black   128 GB
# 1    64 GB ROM | Expandable Upto 1 TB      Royal Blue    64 GB
# 2                          128 GB ROM     Aurora Gold   128 GB
# 3                              128 GB           Green   128 GB
# 4                          128 GB ROM   Glimmer Black   128 GB
# ..                                ...             ...      ...
# 979                        256 GB ROM   Elegant Black   256 GB
# 980  2 MB ROM | Expandable Upto 16 GB             NaN      NaN
# 981                        256 GB ROM    Surfing Blue   256 GB
# 982                        128 GB ROM    Starry Black   128 GB
# 983                            512 GB  White Titanium   512 GB
#
# [984 rows x 13 columns]

# %%
df.drop(columns=['Column2','RAM','Storage'],inplace=True)
df.rename(columns={'RAMM': 'RAM','Column1':'Colour','ROM':'Storage'},inplace=True)

# %%
df
# Out:
#                                                  Name      Price  Warranty  \
# 0                     APPLE iPhone 15 (Black, 128 GB)    ₹73,999       NaN
# 1                        POCO C51 (Royal Blue, 64 GB)     ₹5,799       NaN
# 2                   vivo T2x 5G (Aurora Gold, 128 GB)    ₹14,999       NaN
# 3                     APPLE iPhone 15 (Green, 128 GB)    ₹73,999       NaN
# 4                 vivo T2x 5G (Glimmer Black, 128 GB)    ₹12,999       NaN
# ..                                                ...        ...       ...
# 979               vivo V25 5G (Elegant Black, 256 GB)    ₹26,790       NaN
# 980                        SAMSUNG Metro 313 Dual Sim     ₹2,399       NaN
# 981                vivo V25 5G (Surfing Blue, 256 GB)    ₹27,999       NaN
# 982                   itel S23 (Starry Black, 128 GB)     ₹8,399       NaN
# 983  APPLE iPhone 15 Pro Max (White Titanium, 512 GB)  ₹1,76,900       NaN
#
#        Brand  Rating  Display Size  Primary Camera        RAM  \
# 0      APPLE     4.6           NaN             NaN        NaN
# 1       POCO     4.0           NaN             NaN   4 GB RAM
# 2       vivo     4.3           NaN             NaN   8 GB RAM
# 3      APPLE     4.6           NaN             NaN        NaN
# 4       vivo     4.4           NaN             NaN   6 GB RAM
# ..       ...     ...           ...             ...        ...
# 979     vivo     4.2           NaN             NaN  12 GB RAM
# 980  SAMSUNG     4.3           NaN             NaN  10 MB RAM
# 981     vivo     4.2           NaN             NaN  12 GB RAM
# 982     itel     4.1           NaN             NaN   8 GB RAM
# 983    APPLE     4.7           NaN             NaN        NaN
#
#                               Storage          Colour
# 0                              128 GB           Black
# 1    64 GB ROM | Expandable Upto 1 TB      Royal Blue
# 2                          128 GB ROM     Aurora Gold
# 3                              128 GB           Green
# 4                          128 GB ROM   Glimmer Black
# ..                                ...             ...
# 979                        256 GB ROM   Elegant Black
# 980  2 MB ROM | Expandable Upto 16 GB             NaN
# 981                        256 GB ROM    Surfing Blue
# 982                        128 GB ROM    Starry Black
# 983                            512 GB  White Titanium
#
# [984 rows x 10 columns]

# %%
import re
df['Name'] = df['Name'].apply(lambda x: re.sub(r'\([^)]*\)', '', x))
df['Name'] = df['Name'].apply(lambda x: ' '.join(x.split()[1:]))
df['Storage'] = df['Storage'].str.extract(r'(\d+ GB)')


df
# Out:
#                    Name      Price  Warranty    Brand  Rating  Display Size  \
# 0             iPhone 15    ₹73,999       NaN    APPLE     4.6           NaN
# 1                   C51     ₹5,799       NaN     POCO     4.0           NaN
# 2                T2x 5G    ₹14,999       NaN     vivo     4.3           NaN
# 3             iPhone 15    ₹73,999       NaN    APPLE     4.6           NaN
# 4                T2x 5G    ₹12,999       NaN     vivo     4.4           NaN
# ..                  ...        ...       ...      ...     ...           ...
# 979              V25 5G    ₹26,790       NaN     vivo     4.2           NaN
# 980  Metro 313 Dual Sim     ₹2,399       NaN  SAMSUNG     4.3           NaN
# 981              V25 5G    ₹27,999       NaN     vivo     4.2           NaN
# 982                 S23     ₹8,399       NaN     itel     4.1           NaN
# 983   iPhone 15 Pro Max  ₹1,76,900       NaN    APPLE     4.7           NaN
#
#      Primary Camera        RAM Storage          Colour
# 0               NaN        NaN  128 GB           Black
# 1               NaN   4 GB RAM   64 GB      Royal Blue
# 2               NaN   8 GB RAM  128 GB     Aurora Gold
# 3               NaN        NaN  128 GB           Green
# 4               NaN   6 GB RAM  128 GB   Glimmer Black
# ..              ...        ...     ...             ...
# 979             NaN  12 GB RAM  256 GB   Elegant Black
# 980             NaN  10 MB RAM   16 GB             NaN
# 981             NaN  12 GB RAM  256 GB    Surfing Blue
# 982             NaN   8 GB RAM  128 GB    Starry Black
# 983             NaN        NaN  512 GB  White Titanium
#
# [984 rows x 10 columns]

# %%
df.rename(columns={'Name': 'Model'},inplace=True)
df['Brand'] = df['Brand'].str.capitalize()
df['Model'] = df['Model'].str.capitalize()

# %%
df[df.duplicated()]
df.drop_duplicates(inplace=True)
df.to_excel("mob_info.xlsx", index=False)
